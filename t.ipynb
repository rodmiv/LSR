# %% [markdown]
# # Scryfall Stuff

# %%
import requests
import json
import numpy as np

# %%
res  = requests.get('https://api.scryfall.com/sets')
response = json.loads(res.text)

# %%
for set in response["data"]:
    if set["set_type"] == "expansion":
        print(f"Set Name: {set["name"]}")
        print(f'Set Code: {set["code"]}')
        print('#'*50)

# %%
response['data'][0]
# Out:
# {'object': 'set',
#  'id': '98ffb0ad-639e-4861-b81d-dd5ae734badf',
#  'code': 'tblb',
#  'name': 'Bloomburrow Tokens',
#  'uri': 'https://api.scryfall.com/sets/98ffb0ad-639e-4861-b81d-dd5ae734badf',
#  'scryfall_uri': 'https://scryfall.com/sets/tblb',
#  'search_uri': 'https://api.scryfall.com/cards/search?include_extras=true&include_variations=true&order=set&q=e%3Atblb&unique=prints',
#  'released_at': '2024-08-02',
#  'set_type': 'token',
#  'card_count': 1,
#  'parent_set_code': 'blb',
#  'digital': False,
#  'nonfoil_only': False,
#  'foil_only': False,
#  'icon_svg_uri': 'https://svgs.scryfall.io/sets/blb.svg?1711944000'}

# %% [markdown]
# ### Retrieve a set

# %%
res  = requests.get('https://api.scryfall.com/cards/search?q=set%3Dxln')
response = json.loads(res.text)

# %%
res2 = requests.get(response['next_page'])
response2 = json.loads(res2.text)

# %%
type(response['data'])
# Out:
# list

# %% [markdown]
# # SQLite Stuff

# %% [markdown]
# ### Initial Table

# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
connection = sqlite3.connect('./Data/LSRDB.db')

# %%
set_df = pd.read_sql_query(f"SELECT * FROM blb",connection)

# %%
def type_selection(type_line):
    if type_line.lower().find('creature')>=0:
        return 'creature'
    elif type_line.lower().find('sorcery')>=0:
        return 'sorcery'
    elif type_line.lower().find('instant')>=0:
        return 'instant'
    elif type_line.lower().find('enchantment')>=0:
        return 'enchantment'
    elif type_line.lower().find('artifact')>=0:
        return 'artifact'
    elif type_line.lower().find('land')>=0:
        return 'land'
    elif type_line.lower().find('planeswalker')>=0:
        return 'planeswalker'
    else:
        return 'other'

# %%
set_df['basic_type'] = set_df['type_line_1'].apply(type_selection)

# %%
set_df['basic_type'].value_counts()
# Out:
# basic_type
# creature        163
# instant          36
# sorcery          29
# enchantment      21
# land             17
# artifact         12
# planeswalker      1
# Name: count, dtype: int64

# %%
set_df[set_df['basic_type']=='other']
# Out:
#                               scryfall_id  \
# 180  acfde780-899a-4c5b-a39b-f4a3ff129103
#
#                                 oracle_id                name  layout  \
# 180  3c970f43-17da-4187-a084-efd53b579067  Ral, Crackling Wit  normal
#
#                                            image_uri_1 image_uri_2  \
# 180  https://cards.scryfall.io/normal/front/a/c/acf...          NA
#
#     mana_cost_1 mana_cost_2  cmc                   type_line_1  ...  \
# 180   {2}{U}{R}          NA    4  Legendary Planeswalker — Ral  ...
#
#        colors_1 colors_2 color_identity  keywords  \
# 180  ['R', 'U']       NA     ['R', 'U']        []
#
#                                    set_id     set_name  collector_number  \
# 180  a2f58272-bba6-439d-871e-7a46686ac018  Bloomburrow               230
#
#      rarity booster basic_type
# 180  mythic    True      other
#
# [1 rows x 27 columns]

# %%
cursor = connection.cursor()

# %%
connection.total_changes
# Out:
# 0

# %%
cursor.execute('CREATE TABLE IF NOT EXISTS mtgSets (scryfall_id TEXT, code TEXT, name TEXT, released_at DATE, set_type TEXT, card_count INTEGER, UNIQUE(scryfall_id))')

# %%
connection.commit()

# %%
from utils.sets import sets_list
sets_list()

# %%
for set in response['data']:
    if set['set_type'] == 'expansion':
        print(f'id: {set["id"]}')
        print(f'code: {set["code"]}')
        print(f'name: {set["name"]}')
        print(f'released_at: {set["released_at"]}')
        print(f'set_type: {set["set_type"]}')
        print(f'card_count: {set["card_count"]}')

# %%
connection.commit()

# %%
cursor.execute('''
               CREATE TABLE IF NOT EXISTS xln (
                    scryfall_id TEXT,
                    oracle_id TEXT,
                    name TEXT,
                    layout TEXT, 
                    image_uri_1 TEXT, 
                    image_uri_2 TEXT, 
                    mana_cost_1 TEXT, 
                    mana_cost_2 TEXT, 
                    cmc INTEGER,
                    type_line_1 TEXT,
                    type_line_2 TEXT,
                    oracle_text_1 TEXT,
                    oracle_text_2 TEXT,
                    power_1 INTEGER,
                    power_2 INTEGER,
                    toughness_1 INTEGER,
                    toughness_2 INTEGER,
                    colors_1 TEXT,
                    colors_2 TEXT,
                    color_identity TEXT,
                    keywords TEXT,
                    set_id TEXT,
                    set_name TEXT,
                    collector_number,
                    rarity TEXT,
                    booster BOOLEAN
               )
               ''')

# %%
for card in response['data']:

    # print(json.dumps(card, sort_keys=True, indent=4))
    # print("#"*100)

    pows = {}
    tous = {}

    if 'power' in list(card.keys()):
        pows['pow_1'] = card['power']
        pows['pow_2']  = 999
    elif 'card_faces' in list(card.keys()):        
        count = 1
        for face in card['card_faces']:
            if 'power' in list(face.keys()):
                pows[f'pow_{count}'] = face['power']
            else:
                pows[f'pow_{count}'] = 999
            count+=1
    else:
        pows['pow_1'] = 999
        pows['pow_2'] = 999
    
    if 'toughness' in list(card.keys()):
        tous['tou_1'] = card['toughness']
        tous['tou_2']  = 999
    elif 'card_faces' in list(card.keys()):        
        count = 1
        for face in card['card_faces']:
            if 'toughness' in list(face.keys()):
                tous[f'tou_{count}'] = face['toughness']
            else:
                tous[f'tou_{count}'] = 999
            count+=1
    else:
        tous['tou_1']  = 999
        tous['tou_2']  = 999

    try:
        card_text_1 = card['oracle_text'].replace('"','').replace("'",'')
        card_text_2 = "NA"
    except:
        card_text = [face['oracle_text'] for face in card['card_faces']]

        card_text_1 = card_text[0].replace('"','').replace("'",'')
        card_text_2 = card_text[1].replace('"','').replace("'",'')

    try:
        image_uri_1 = card['image_uris']['normal']
        image_uri_2 = "NA"
    except:
        image_uris = [face['image_uris']['normal'] for face in card['card_faces']]

        image_uri_1 = image_uris[0]
        image_uri_2 = image_uris[1]

    try:
        mana_cost_1 = card['mana_cost']
        mana_cost_2 = "NA"
    except:
        mana_costs = [face['mana_cost'] for face in card['card_faces']]

        mana_cost_1 = mana_costs[0]
        mana_cost_2 = mana_costs[1]

    try:        
        type_1 = card['type_line']
        type_2 = "NA"
    except:
        types = [face['type_line'] for face in card['card_faces']]

        type_1 = types[0]
        type_2 = types[1]

    try:        
        colors_1 = card['colors']
        colors_2 = "NA"
    except:
        colorss = [face['colors'] for face in card['card_faces']]

        colors_1 = colorss[0]
        colors_2 = colorss[1]
        

    cursor.execute(f'''
                        INSERT INTO xln VALUES (
                            '{card['id']}',
                            '{card['oracle_id']}',
                            "{card['name'].replace('"','').replace("'",'')}",
                            '{card['layout']}',
                            '{image_uri_1}',
                            '{image_uri_2}',
                            '{mana_cost_1}',
                            '{mana_cost_2}',
                            {card['cmc']},
                            '{type_1}',
                            '{type_2}',
                            '{card_text_1}',
                            '{card_text_2}',
                            {pows['pow_1']},
                            {pows['pow_2']},
                            {tous['tou_1']},
                            {tous['tou_2']},
                            "{colors_1}",
                            "{colors_2}",
                            "{card['color_identity']}",
                            "{card['keywords']}",
                            '{card['set_id']}',
                            '{card['set_name']}',
                            '{card['collector_number']}',
                            '{card['rarity']}',
                            '{card['booster']}'
                            )
                    ''')
# Out:
# {
#     "arena_id": 65961,
#     "artist": "Anna Steinbauer",
#     "artist_ids": [
#         "3516496c-c279-4b56-8239-720683d03ae0"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 301689,
#     "cmc": 2.0,
#     "collector_number": "1",
#     "color_identity": [
#         "W"
#     ],
#     "colors": [
#         "W"
#     ],
#     "digital": false,
#     "edhrec_rank": 11935,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "foil": true,
#     "frame": "2015",
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "21c950d7-b4f6-4902-8c9a-98f2933f9fa5",
#     "illustration_id": "9e1bc3e7-2541-4a83-842a-70550a260f5e",
#     "image_status": "highres_scan",
#     "image_uris": {
#         "art_crop": "https://cards.scryfall.io/art_crop/front/2/1/21c950d7-b4f6-4902-8c9a-98f2933f9fa5.jpg?1562552020",
#         "border_crop": "https://cards.scryfall.io/border_crop/front/2/1/21c950d7-b4f6-4902-8c9a-98f2933f9fa5.jpg?1562552020",
#         "large": "https://cards.scryfall.io/large/front/2/1/21c950d7-b4f6-4902-8c9a-98f2933f9fa5.jpg?1562552020",
#         "normal": "https://cards.scryfall.io/normal/front/2/1/21c950d7-b4f6-4902-8c9a-98f2933f9fa5.jpg?1562552020",
#         "png": "https://cards.scryfall.io/png/front/2/1/21c950d7-b4f6-4902-8c9a-98f2933f9fa5.png?1562552020",
#         "small": "https://cards.scryfall.io/small/front/2/1/21c950d7-b4f6-4902-8c9a-98f2933f9fa5.jpg?1562552020"
#     },
#     "keywords": [],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "not_legal",
#         "paupercommander": "restricted",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{1}{W}",
#     "mtgo_foil_id": 65013,
#     "mtgo_id": 65012,
#     "multiverse_ids": [
#         435152
#     ],
#     "name": "Adanto Vanguard",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "91c380f6-2c41-48b7-9f07-104e8659e397",
#     "oracle_text": "As long as Adanto Vanguard is attacking, it gets +2/+0.\nPay 4 life: Adanto Vanguard gains indestructible until end of turn. (Damage and effects that say \"destroy\" don't destroy it.)",
#     "oversized": false,
#     "penny_rank": 1277,
#     "power": "1",
#     "prices": {
#         "eur": "0.16",
#         "eur_foil": "1.17",
#         "tix": "0.03",
#         "usd": "0.18",
#         "usd_etched": null,
#         "usd_foil": "1.83"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3A91c380f6-2c41-48b7-9f07-104e8659e397&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65012?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Adanto-Vanguard?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F145587%3Fpage%3D1"
#     },
#     "rarity": "uncommon",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Adanto+Vanguard",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435152&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DAdanto%2BVanguard",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DAdanto%2BVanguard"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/21c950d7-b4f6-4902-8c9a-98f2933f9fa5/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/1/adanto-vanguard?utm_source=api",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 145587,
#     "textless": false,
#     "toughness": "1",
#     "type_line": "Creature \u2014 Vampire Soldier",
#     "uri": "https://api.scryfall.com/cards/21c950d7-b4f6-4902-8c9a-98f2933f9fa5",
#     "variation": false
# }
# ####################################################################################################
# {
#     "all_parts": [
#         {
#             "component": "combo_piece",
#             "id": "577304f8-89e5-47d2-bdb3-311d4be88af2",
#             "name": "Brazen Boarding",
#             "object": "related_card",
#             "type_line": "Sorcery",
#             "uri": "https://api.scryfall.com/cards/577304f8-89e5-47d2-bdb3-311d4be88af2"
#         },
#         {
#             "component": "combo_piece",
#             "id": "9854c2ec-0e53-4ac7-b417-554a9331c5e0",
#             "name": "Admiral Beckett Brass",
#             "object": "related_card",
#             "type_line": "Legendary Creature \u2014 Human Pirate",
#             "uri": "https://api.scryfall.com/cards/9854c2ec-0e53-4ac7-b417-554a9331c5e0"
#         }
#     ],
#     "arena_id": 66403,
#     "artist": "Jason Rainville",
#     "artist_ids": [
#         "6ed7e669-579b-443d-b223-e5cbcb2a7483"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 301225,
#     "cmc": 4.0,
#     "collector_number": "217",
#     "color_identity": [
#         "B",
#         "R",
#         "U"
#     ],
#     "colors": [
#         "B",
#         "R",
#         "U"
#     ],
#     "digital": false,
#     "edhrec_rank": 5101,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "flavor_text": "\"You and your ship will make a fine addition to my fleet.\"",
#     "foil": true,
#     "frame": "2015",
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "9854c2ec-0e53-4ac7-b417-554a9331c5e0",
#     "illustration_id": "8590b2be-8a63-4221-a043-d6b40fd2bc91",
#     "image_status": "highres_scan",
#     "image_uris": {
#         "art_crop": "https://cards.scryfall.io/art_crop/front/9/8/9854c2ec-0e53-4ac7-b417-554a9331c5e0.jpg?1562560523",
#         "border_crop": "https://cards.scryfall.io/border_crop/front/9/8/9854c2ec-0e53-4ac7-b417-554a9331c5e0.jpg?1562560523",
#         "large": "https://cards.scryfall.io/large/front/9/8/9854c2ec-0e53-4ac7-b417-554a9331c5e0.jpg?1562560523",
#         "normal": "https://cards.scryfall.io/normal/front/9/8/9854c2ec-0e53-4ac7-b417-554a9331c5e0.jpg?1562560523",
#         "png": "https://cards.scryfall.io/png/front/9/8/9854c2ec-0e53-4ac7-b417-554a9331c5e0.png?1562560523",
#         "small": "https://cards.scryfall.io/small/front/9/8/9854c2ec-0e53-4ac7-b417-554a9331c5e0.jpg?1562560523"
#     },
#     "keywords": [],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "not_legal",
#         "paupercommander": "not_legal",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{1}{U}{B}{R}",
#     "mtgo_foil_id": 65455,
#     "mtgo_id": 65454,
#     "multiverse_ids": [
#         435373
#     ],
#     "name": "Admiral Beckett Brass",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "43b5e462-d860-473d-828f-6c513fc7768a",
#     "oracle_text": "Other Pirates you control get +1/+1.\nAt the beginning of your end step, gain control of target nonland permanent controlled by a player who was dealt combat damage by three or more Pirates this turn.",
#     "oversized": false,
#     "penny_rank": 10606,
#     "power": "3",
#     "prices": {
#         "eur": "0.68",
#         "eur_foil": "10.48",
#         "tix": "0.02",
#         "usd": "0.78",
#         "usd_etched": null,
#         "usd_foil": "11.07"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3A43b5e462-d860-473d-828f-6c513fc7768a&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65454?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Admiral-Beckett-Brass?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F142029%3Fpage%3D1"
#     },
#     "rarity": "mythic",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Admiral+Beckett+Brass",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435373&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DAdmiral%2BBeckett%2BBrass",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DAdmiral%2BBeckett%2BBrass"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/9854c2ec-0e53-4ac7-b417-554a9331c5e0/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/217/admiral-beckett-brass?utm_source=api",
#     "security_stamp": "oval",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 142029,
#     "textless": false,
#     "toughness": "3",
#     "type_line": "Legendary Creature \u2014 Human Pirate",
#     "uri": "https://api.scryfall.com/cards/9854c2ec-0e53-4ac7-b417-554a9331c5e0",
#     "variation": false
# }
# ####################################################################################################
# {
#     "arena_id": 66051,
#     "artist": "Tomasz Jedruszek",
#     "artist_ids": [
#         "bba69285-2445-4a4b-a847-59397be972ea"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 301753,
#     "cmc": 5.0,
#     "collector_number": "45",
#     "color_identity": [
#         "U"
#     ],
#     "colors": [
#         "U"
#     ],
#     "digital": false,
#     "edhrec_rank": 20019,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "flavor_text": "As the ship approached, the jade totem rose high overhead. Power rippled. Eyes of stone glowed and crackled. Out hissed a breath of the world, and a windstorm came alive.",
#     "foil": true,
#     "frame": "2015",
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "0fc9ba0a-2840-48cb-8cf4-ef2a5f273849",
#     "illustration_id": "843020fe-092f-47ab-a2e5-8a37065ff90d",
#     "image_status": "highres_scan",
#     "image_uris": {
#         "art_crop": "https://cards.scryfall.io/art_crop/front/0/f/0fc9ba0a-2840-48cb-8cf4-ef2a5f273849.jpg?1562550802",
#         "border_crop": "https://cards.scryfall.io/border_crop/front/0/f/0fc9ba0a-2840-48cb-8cf4-ef2a5f273849.jpg?1562550802",
#         "large": "https://cards.scryfall.io/large/front/0/f/0fc9ba0a-2840-48cb-8cf4-ef2a5f273849.jpg?1562550802",
#         "normal": "https://cards.scryfall.io/normal/front/0/f/0fc9ba0a-2840-48cb-8cf4-ef2a5f273849.jpg?1562550802",
#         "png": "https://cards.scryfall.io/png/front/0/f/0fc9ba0a-2840-48cb-8cf4-ef2a5f273849.png?1562550802",
#         "small": "https://cards.scryfall.io/small/front/0/f/0fc9ba0a-2840-48cb-8cf4-ef2a5f273849.jpg?1562550802"
#     },
#     "keywords": [
#         "Flying"
#     ],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "not_legal",
#         "paupercommander": "restricted",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "legal",
#         "premodern": "legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{3}{U}{U}",
#     "mtgo_foil_id": 65103,
#     "mtgo_id": 65102,
#     "multiverse_ids": [
#         435197
#     ],
#     "name": "Air Elemental",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "7744bae4-a8b7-44a5-9b4c-0048ad4cc448",
#     "oracle_text": "Flying",
#     "oversized": false,
#     "penny_rank": 7231,
#     "power": "4",
#     "prices": {
#         "eur": "0.04",
#         "eur_foil": "0.23",
#         "tix": "0.03",
#         "usd": "0.03",
#         "usd_etched": null,
#         "usd_foil": "0.35"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3A7744bae4-a8b7-44a5-9b4c-0048ad4cc448&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65102?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Air-Elemental?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F145739%3Fpage%3D1"
#     },
#     "rarity": "uncommon",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Air+Elemental",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435197&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DAir%2BElemental",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DAir%2BElemental"
#     },
#     "released_at": "2017-09-29",
#     "reprint": true,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/0fc9ba0a-2840-48cb-8cf4-ef2a5f273849/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/45/air-elemental?utm_source=api",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 145739,
#     "textless": false,
#     "toughness": "4",
#     "type_line": "Creature \u2014 Elemental",
#     "uri": "https://api.scryfall.com/cards/0fc9ba0a-2840-48cb-8cf4-ef2a5f273849",
#     "variation": false
# }
# ####################################################################################################
# {
#     "arena_id": 66317,
#     "artist": "Jakub Kasper",
#     "artist_ids": [
#         "36901417-ce61-4636-8b77-6db14a9cb68a"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 301725,
#     "cmc": 8.0,
#     "collector_number": "175",
#     "color_identity": [
#         "G"
#     ],
#     "colors": [
#         "G"
#     ],
#     "digital": false,
#     "edhrec_rank": 10236,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "flavor_text": "It is taller than all but the tallest trees, and older than all but the oldest.",
#     "foil": true,
#     "frame": "2015",
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "39421ce8-86d5-4739-b6fd-78d63c0bb258",
#     "illustration_id": "cb6eb1cd-d08c-4612-9883-4ab8839ce47d",
#     "image_status": "highres_scan",
#     "image_uris": {
#         "art_crop": "https://cards.scryfall.io/art_crop/front/3/9/39421ce8-86d5-4739-b6fd-78d63c0bb258.jpg?1562553559",
#         "border_crop": "https://cards.scryfall.io/border_crop/front/3/9/39421ce8-86d5-4739-b6fd-78d63c0bb258.jpg?1562553559",
#         "large": "https://cards.scryfall.io/large/front/3/9/39421ce8-86d5-4739-b6fd-78d63c0bb258.jpg?1562553559",
#         "normal": "https://cards.scryfall.io/normal/front/3/9/39421ce8-86d5-4739-b6fd-78d63c0bb258.jpg?1562553559",
#         "png": "https://cards.scryfall.io/png/front/3/9/39421ce8-86d5-4739-b6fd-78d63c0bb258.png?1562553559",
#         "small": "https://cards.scryfall.io/small/front/3/9/39421ce8-86d5-4739-b6fd-78d63c0bb258.jpg?1562553559"
#     },
#     "keywords": [],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "legal",
#         "paupercommander": "legal",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{6}{G}{G}",
#     "mtgo_foil_id": 65369,
#     "mtgo_id": 65368,
#     "multiverse_ids": [
#         435330
#     ],
#     "name": "Ancient Brontodon",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "745be03c-69dc-4239-a5e7-38587b56eac0",
#     "oracle_text": "",
#     "oversized": false,
#     "penny_rank": 7244,
#     "power": "9",
#     "prices": {
#         "eur": "0.09",
#         "eur_foil": "0.20",
#         "tix": "0.03",
#         "usd": "0.10",
#         "usd_etched": null,
#         "usd_foil": "0.36"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3A745be03c-69dc-4239-a5e7-38587b56eac0&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65368?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Ancient-Brontodon?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F145670%3Fpage%3D1"
#     },
#     "rarity": "common",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Ancient+Brontodon",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435330&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DAncient%2BBrontodon",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DAncient%2BBrontodon"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/39421ce8-86d5-4739-b6fd-78d63c0bb258/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/175/ancient-brontodon?utm_source=api",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 145670,
#     "textless": false,
#     "toughness": "9",
#     "type_line": "Creature \u2014 Dinosaur",
#     "uri": "https://api.scryfall.com/cards/39421ce8-86d5-4739-b6fd-78d63c0bb258",
#     "variation": false
# }
# ####################################################################################################
# {
#     "arena_id": 66229,
#     "artist": "Victor Adame Minguez",
#     "artist_ids": [
#         "bd8f7368-5b10-4554-b6b8-d052c6aca89f"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 301212,
#     "cmc": 7.0,
#     "collector_number": "132",
#     "color_identity": [
#         "R"
#     ],
#     "colors": [
#         "R"
#     ],
#     "digital": false,
#     "edhrec_rank": 2209,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "flavor_text": "Captain Angrath cares less about treasure than mayhem. If he can't leave Ixalan, he'll burn the plane down.",
#     "foil": true,
#     "frame": "2015",
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "f0bfc9e0-14e8-43ce-8fca-773b7f2387dc",
#     "illustration_id": "bab8eb43-347e-47d3-b276-3d609b24e957",
#     "image_status": "highres_scan",
#     "image_uris": {
#         "art_crop": "https://cards.scryfall.io/art_crop/front/f/0/f0bfc9e0-14e8-43ce-8fca-773b7f2387dc.jpg?1562566421",
#         "border_crop": "https://cards.scryfall.io/border_crop/front/f/0/f0bfc9e0-14e8-43ce-8fca-773b7f2387dc.jpg?1562566421",
#         "large": "https://cards.scryfall.io/large/front/f/0/f0bfc9e0-14e8-43ce-8fca-773b7f2387dc.jpg?1562566421",
#         "normal": "https://cards.scryfall.io/normal/front/f/0/f0bfc9e0-14e8-43ce-8fca-773b7f2387dc.jpg?1562566421",
#         "png": "https://cards.scryfall.io/png/front/f/0/f0bfc9e0-14e8-43ce-8fca-773b7f2387dc.png?1562566421",
#         "small": "https://cards.scryfall.io/small/front/f/0/f0bfc9e0-14e8-43ce-8fca-773b7f2387dc.jpg?1562566421"
#     },
#     "keywords": [],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "not_legal",
#         "paupercommander": "not_legal",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{5}{R}{R}",
#     "mtgo_foil_id": 65281,
#     "mtgo_id": 65280,
#     "multiverse_ids": [
#         435286
#     ],
#     "name": "Angrath's Marauders",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "2d4976d4-649c-4d42-ac5a-ada4b46a480c",
#     "oracle_text": "If a source you control would deal damage to a permanent or player, it deals double that damage to that permanent or player instead.",
#     "oversized": false,
#     "penny_rank": 12309,
#     "power": "4",
#     "prices": {
#         "eur": "0.67",
#         "eur_foil": "1.94",
#         "tix": "0.02",
#         "usd": "0.58",
#         "usd_etched": null,
#         "usd_foil": "4.25"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3A2d4976d4-649c-4d42-ac5a-ada4b46a480c&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65280?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Angrath-s-Marauders?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F142015%3Fpage%3D1"
#     },
#     "rarity": "rare",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Angrath%27s+Marauders",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435286&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DAngrath%2527s%2BMarauders",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DAngrath%2527s%2BMarauders"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/f0bfc9e0-14e8-43ce-8fca-773b7f2387dc/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/132/angraths-marauders?utm_source=api",
#     "security_stamp": "oval",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 142015,
#     "textless": false,
#     "toughness": "4",
#     "type_line": "Creature \u2014 Human Pirate",
#     "uri": "https://api.scryfall.com/cards/f0bfc9e0-14e8-43ce-8fca-773b7f2387dc",
#     "variation": false
# }
# ####################################################################################################
# {
#     "arena_id": 66141,
#     "artist": "Winona Nelson",
#     "artist_ids": [
#         "e45fe8d3-75d6-42c9-a2df-e945ad81ea27"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 301772,
#     "cmc": 5.0,
#     "collector_number": "89",
#     "color_identity": [
#         "B"
#     ],
#     "colors": [
#         "B"
#     ],
#     "digital": false,
#     "edhrec_rank": 20699,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "flavor_text": "Inspiration is red as rubies, flowing like honeyed wine.",
#     "foil": true,
#     "frame": "2015",
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "9bae5e75-0048-41fd-8bbb-89607ab96d6e",
#     "illustration_id": "1d4b5993-e534-4441-8bc5-0fd898019e42",
#     "image_status": "highres_scan",
#     "image_uris": {
#         "art_crop": "https://cards.scryfall.io/art_crop/front/9/b/9bae5e75-0048-41fd-8bbb-89607ab96d6e.jpg?1562560768",
#         "border_crop": "https://cards.scryfall.io/border_crop/front/9/b/9bae5e75-0048-41fd-8bbb-89607ab96d6e.jpg?1562560768",
#         "large": "https://cards.scryfall.io/large/front/9/b/9bae5e75-0048-41fd-8bbb-89607ab96d6e.jpg?1562560768",
#         "normal": "https://cards.scryfall.io/normal/front/9/b/9bae5e75-0048-41fd-8bbb-89607ab96d6e.jpg?1562560768",
#         "png": "https://cards.scryfall.io/png/front/9/b/9bae5e75-0048-41fd-8bbb-89607ab96d6e.png?1562560768",
#         "small": "https://cards.scryfall.io/small/front/9/b/9bae5e75-0048-41fd-8bbb-89607ab96d6e.jpg?1562560768"
#     },
#     "keywords": [],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "legal",
#         "paupercommander": "legal",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{4}{B}",
#     "mtgo_foil_id": 65193,
#     "mtgo_id": 65192,
#     "multiverse_ids": [
#         435242
#     ],
#     "name": "Anointed Deacon",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "5212f0a8-7341-4960-835b-2f4600ca1b2d",
#     "oracle_text": "At the beginning of combat on your turn, you may have target Vampire get +2/+0 until end of turn.",
#     "oversized": false,
#     "penny_rank": 10083,
#     "power": "3",
#     "prices": {
#         "eur": "0.05",
#         "eur_foil": "0.22",
#         "tix": "0.03",
#         "usd": "0.04",
#         "usd_etched": null,
#         "usd_foil": "0.12"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3A5212f0a8-7341-4960-835b-2f4600ca1b2d&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65192?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Anointed-Deacon?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F145775%3Fpage%3D1"
#     },
#     "rarity": "common",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Anointed+Deacon",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435242&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DAnointed%2BDeacon",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DAnointed%2BDeacon"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/9bae5e75-0048-41fd-8bbb-89607ab96d6e/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/89/anointed-deacon?utm_source=api",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 145775,
#     "textless": false,
#     "toughness": "3",
#     "type_line": "Creature \u2014 Vampire Cleric",
#     "uri": "https://api.scryfall.com/cards/9bae5e75-0048-41fd-8bbb-89607ab96d6e",
#     "variation": false
# }
# ####################################################################################################
# {
#     "arena_id": 66053,
#     "artist": "Mark Behm",
#     "artist_ids": [
#         "ccf77963-723f-4137-b364-7417079e8ab9"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 298490,
#     "cmc": 3.0,
#     "collector_number": "46",
#     "color_identity": [
#         "U"
#     ],
#     "colors": [
#         "U"
#     ],
#     "digital": false,
#     "edhrec_rank": 2586,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "foil": true,
#     "frame": "2015",
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "bf3edaaf-cf63-4e17-94ae-9d9991d9fb5f",
#     "illustration_id": "6dfc42e2-4352-411d-b346-082511541d1c",
#     "image_status": "highres_scan",
#     "image_uris": {
#         "art_crop": "https://cards.scryfall.io/art_crop/front/b/f/bf3edaaf-cf63-4e17-94ae-9d9991d9fb5f.jpg?1562563280",
#         "border_crop": "https://cards.scryfall.io/border_crop/front/b/f/bf3edaaf-cf63-4e17-94ae-9d9991d9fb5f.jpg?1562563280",
#         "large": "https://cards.scryfall.io/large/front/b/f/bf3edaaf-cf63-4e17-94ae-9d9991d9fb5f.jpg?1562563280",
#         "normal": "https://cards.scryfall.io/normal/front/b/f/bf3edaaf-cf63-4e17-94ae-9d9991d9fb5f.jpg?1562563280",
#         "png": "https://cards.scryfall.io/png/front/b/f/bf3edaaf-cf63-4e17-94ae-9d9991d9fb5f.png?1562563280",
#         "small": "https://cards.scryfall.io/small/front/b/f/bf3edaaf-cf63-4e17-94ae-9d9991d9fb5f.jpg?1562563280"
#     },
#     "keywords": [],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "not_legal",
#         "paupercommander": "not_legal",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{2}{U}",
#     "mtgo_foil_id": 65105,
#     "mtgo_id": 65104,
#     "multiverse_ids": [
#         435198
#     ],
#     "name": "Arcane Adaptation",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "2188c03f-11b6-4651-914a-b4fdd59127e3",
#     "oracle_text": "As Arcane Adaptation enters the battlefield, choose a creature type.\nCreatures you control are the chosen type in addition to their other types. The same is true for creature spells you control and creature cards you own that aren't on the battlefield.",
#     "oversized": false,
#     "penny_rank": 5347,
#     "prices": {
#         "eur": "2.59",
#         "eur_foil": "3.71",
#         "tix": "0.02",
#         "usd": "4.40",
#         "usd_etched": null,
#         "usd_foil": "4.58"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3A2188c03f-11b6-4651-914a-b4fdd59127e3&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65104?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Arcane-Adaptation?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F142001%3Fpage%3D1"
#     },
#     "rarity": "rare",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Arcane+Adaptation",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435198&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DArcane%2BAdaptation",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DArcane%2BAdaptation"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/bf3edaaf-cf63-4e17-94ae-9d9991d9fb5f/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/46/arcane-adaptation?utm_source=api",
#     "security_stamp": "oval",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 142001,
#     "textless": false,
#     "type_line": "Enchantment",
#     "uri": "https://api.scryfall.com/cards/bf3edaaf-cf63-4e17-94ae-9d9991d9fb5f",
#     "variation": false
# }
# ####################################################################################################
# {
#     "all_parts": [
#         {
#             "component": "combo_piece",
#             "id": "4a8b3030-5495-404b-938c-8c4a387a1341",
#             "name": "Ixalan Checklist",
#             "object": "related_card",
#             "type_line": "Card",
#             "uri": "https://api.scryfall.com/cards/4a8b3030-5495-404b-938c-8c4a387a1341"
#         },
#         {
#             "component": "combo_piece",
#             "id": "c4ac7570-e74e-4081-ac53-cf41e695b7eb",
#             "name": "Arguel's Blood Fast // Temple of Aclazotz",
#             "object": "related_card",
#             "type_line": "Legendary Enchantment // Legendary Land",
#             "uri": "https://api.scryfall.com/cards/c4ac7570-e74e-4081-ac53-cf41e695b7eb"
#         },
#         {
#             "component": "combo_piece",
#             "id": "31d2e591-6df4-4445-a16c-c7a576ff3e20",
#             "name": "High Marshal Arguel",
#             "object": "related_card",
#             "type_line": "Legendary Creature \u2014 Vampire Knight",
#             "uri": "https://api.scryfall.com/cards/31d2e591-6df4-4445-a16c-c7a576ff3e20"
#         }
#     ],
#     "arena_id": 66143,
#     "artist": "Daarken",
#     "artist_ids": [
#         "e607a0d4-fc12-4c01-9e3f-501f5269b9cb"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_faces": [
#         {
#             "artist": "Daarken",
#             "artist_id": "e607a0d4-fc12-4c01-9e3f-501f5269b9cb",
#             "colors": [
#                 "B"
#             ],
#             "flavor_text": "Arguel's vision led him into the jungles of Ixalan . . .",
#             "illustration_id": "a1e9f54d-adde-4c8a-acd0-5c63c2fece55",
#             "image_uris": {
#                 "art_crop": "https://cards.scryfall.io/art_crop/front/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598",
#                 "border_crop": "https://cards.scryfall.io/border_crop/front/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598",
#                 "large": "https://cards.scryfall.io/large/front/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598",
#                 "normal": "https://cards.scryfall.io/normal/front/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598",
#                 "png": "https://cards.scryfall.io/png/front/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.png?1562563598",
#                 "small": "https://cards.scryfall.io/small/front/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598"
#             },
#             "mana_cost": "{1}{B}",
#             "name": "Arguel's Blood Fast",
#             "object": "card_face",
#             "oracle_text": "{1}{B}, Pay 2 life: Draw a card.\nAt the beginning of your upkeep, if you have 5 or less life, you may transform Arguel's Blood Fast.",
#             "type_line": "Legendary Enchantment"
#         },
#         {
#             "artist": "Daarken",
#             "artist_id": "e607a0d4-fc12-4c01-9e3f-501f5269b9cb",
#             "colors": [],
#             "flavor_name": "",
#             "flavor_text": ". . . to the lost temple of a bat-god of night, eternal enemy to the Threefold Sun.",
#             "illustration_id": "872bd01d-10b1-4050-84e8-bf128e624b6d",
#             "image_uris": {
#                 "art_crop": "https://cards.scryfall.io/art_crop/back/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598",
#                 "border_crop": "https://cards.scryfall.io/border_crop/back/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598",
#                 "large": "https://cards.scryfall.io/large/back/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598",
#                 "normal": "https://cards.scryfall.io/normal/back/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598",
#                 "png": "https://cards.scryfall.io/png/back/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.png?1562563598",
#                 "small": "https://cards.scryfall.io/small/back/c/4/c4ac7570-e74e-4081-ac53-cf41e695b7eb.jpg?1562563598"
#             },
#             "mana_cost": "",
#             "name": "Temple of Aclazotz",
#             "object": "card_face",
#             "oracle_text": "(Transforms from Arguel's Blood Fast.)\n{T}: Add {B}.\n{T}, Sacrifice a creature: You gain life equal to the sacrificed creature's toughness.",
#             "type_line": "Legendary Land"
#         }
#     ],
#     "cardmarket_id": 301387,
#     "cmc": 2.0,
#     "collector_number": "90",
#     "color_identity": [
#         "B"
#     ],
#     "digital": false,
#     "edhrec_rank": 5199,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "foil": true,
#     "frame": "2015",
#     "frame_effects": [
#         "compasslanddfc"
#     ],
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "c4ac7570-e74e-4081-ac53-cf41e695b7eb",
#     "image_status": "highres_scan",
#     "keywords": [
#         "Transform"
#     ],
#     "lang": "en",
#     "layout": "transform",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "not_legal",
#         "paupercommander": "not_legal",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mtgo_foil_id": 65195,
#     "mtgo_id": 65194,
#     "multiverse_ids": [
#         435243,
#         435244
#     ],
#     "name": "Arguel's Blood Fast // Temple of Aclazotz",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "be2a4bc4-8af6-48c5-9421-32d26272e71a",
#     "oversized": false,
#     "penny_rank": 2656,
#     "prices": {
#         "eur": "0.27",
#         "eur_foil": "1.16",
#         "tix": "0.02",
#         "usd": "0.35",
#         "usd_etched": null,
#         "usd_foil": "0.84"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3Abe2a4bc4-8af6-48c5-9421-32d26272e71a&unique=prints",
#     "produced_mana": [
#         "B"
#     ],
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65194?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Arguels-Blood-Fast-Temple-of-Aclazotz?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F145261%3Fpage%3D1"
#     },
#     "rarity": "rare",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Arguel%27s+Blood+Fast",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435243&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DArguel%2527s%2BBlood%2BFast%2B%252F%252F%2BTemple%2Bof%2BAclazotz",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DArguel%2527s%2BBlood%2BFast%2B%252F%252F%2BTemple%2Bof%2BAclazotz"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/c4ac7570-e74e-4081-ac53-cf41e695b7eb/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/90/arguels-blood-fast-temple-of-aclazotz?utm_source=api",
#     "security_stamp": "oval",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 145261,
#     "textless": false,
#     "type_line": "Legendary Enchantment // Legendary Land",
#     "uri": "https://api.scryfall.com/cards/c4ac7570-e74e-4081-ac53-cf41e695b7eb",
#     "variation": false
# }
# ####################################################################################################
# {
#     "arena_id": 65963,
#     "artist": "Daarken",
#     "artist_ids": [
#         "e607a0d4-fc12-4c01-9e3f-501f5269b9cb"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 301191,
#     "cmc": 2.0,
#     "collector_number": "2",
#     "color_identity": [
#         "W"
#     ],
#     "colors": [
#         "W"
#     ],
#     "digital": false,
#     "edhrec_rank": 5567,
#     "finishes": [
# ...
#         "large": "https://cards.scryfall.io/large/front/3/0/309b204b-774a-47bc-aead-c78db90f3be2.jpg?1562552903",
#         "normal": "https://cards.scryfall.io/normal/front/3/0/309b204b-774a-47bc-aead-c78db90f3be2.jpg?1562552903",
#         "png": "https://cards.scryfall.io/png/front/3/0/309b204b-774a-47bc-aead-c78db90f3be2.png?1562552903",
#         "small": "https://cards.scryfall.io/small/front/3/0/309b204b-774a-47bc-aead-c78db90f3be2.jpg?1562552903"
#     },
#     "keywords": [
#         "Enrage"
#     ],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "legal",
#         "paupercommander": "legal",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{2}{G}",
#     "mtgo_foil_id": 65425,
#     "mtgo_id": 65424,
#     "multiverse_ids": [
#         435358
#     ],
#     "name": "Ravenous Daggertooth",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "f5ef25fb-545e-41b7-8fed-d3cfff3d8668",
#     "oracle_text": "Enrage \u2014 Whenever Ravenous Daggertooth is dealt damage, you gain 2 life.",
#     "oversized": false,
#     "penny_rank": 11899,
#     "power": "3",
#     "prices": {
#         "eur": "0.15",
#         "eur_foil": "0.23",
#         "tix": "0.03",
#         "usd": "0.07",
#         "usd_etched": null,
#         "usd_foil": "0.37"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3Af5ef25fb-545e-41b7-8fed-d3cfff3d8668&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65424?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Ravenous-Daggertooth?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F145256%3Fpage%3D1"
#     },
#     "rarity": "common",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Ravenous+Daggertooth",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435358&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DRavenous%2BDaggertooth",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DRavenous%2BDaggertooth"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/309b204b-774a-47bc-aead-c78db90f3be2/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/202/ravenous-daggertooth?utm_source=api",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 145256,
#     "textless": false,
#     "toughness": "2",
#     "type_line": "Creature \u2014 Dinosaur",
#     "uri": "https://api.scryfall.com/cards/309b204b-774a-47bc-aead-c78db90f3be2",
#     "variation": false
# }
# ####################################################################################################
# {
#     "all_parts": [
#         {
#             "component": "combo_piece",
#             "id": "d6a322c5-aa4c-4a99-a3ca-48c1353104f0",
#             "name": "Regisaur Alpha",
#             "object": "related_card",
#             "type_line": "Creature \u2014 Dinosaur",
#             "uri": "https://api.scryfall.com/cards/d6a322c5-aa4c-4a99-a3ca-48c1353104f0"
#         },
#         {
#             "component": "token",
#             "id": "1ccee594-e1e6-4a82-bc17-93bcdeb36198",
#             "name": "Dinosaur",
#             "object": "related_card",
#             "type_line": "Token Creature \u2014 Dinosaur",
#             "uri": "https://api.scryfall.com/cards/1ccee594-e1e6-4a82-bc17-93bcdeb36198"
#         }
#     ],
#     "arena_id": 66423,
#     "artist": "Jonathan Kuo",
#     "artist_ids": [
#         "babb75bd-4c75-4b13-ad61-c34597ab79ff"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 301385,
#     "cmc": 5.0,
#     "collector_number": "227",
#     "color_identity": [
#         "G",
#         "R"
#     ],
#     "colors": [
#         "G",
#         "R"
#     ],
#     "digital": false,
#     "edhrec_rank": 2057,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "flavor_text": "\"Seeing a pack of these monsters hunt together, I'm at a loss to imagine the size of their prey.\"\n\u2014Adrian Adanto of Lujio",
#     "foil": true,
#     "frame": "2015",
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "d6a322c5-aa4c-4a99-a3ca-48c1353104f0",
#     "illustration_id": "5905040a-0b03-497a-9f9a-114e972736de",
#     "image_status": "highres_scan",
#     "image_uris": {
#         "art_crop": "https://cards.scryfall.io/art_crop/front/d/6/d6a322c5-aa4c-4a99-a3ca-48c1353104f0.jpg?1562564727",
#         "border_crop": "https://cards.scryfall.io/border_crop/front/d/6/d6a322c5-aa4c-4a99-a3ca-48c1353104f0.jpg?1562564727",
#         "large": "https://cards.scryfall.io/large/front/d/6/d6a322c5-aa4c-4a99-a3ca-48c1353104f0.jpg?1562564727",
#         "normal": "https://cards.scryfall.io/normal/front/d/6/d6a322c5-aa4c-4a99-a3ca-48c1353104f0.jpg?1562564727",
#         "png": "https://cards.scryfall.io/png/front/d/6/d6a322c5-aa4c-4a99-a3ca-48c1353104f0.png?1562564727",
#         "small": "https://cards.scryfall.io/small/front/d/6/d6a322c5-aa4c-4a99-a3ca-48c1353104f0.jpg?1562564727"
#     },
#     "keywords": [],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "not_legal",
#         "paupercommander": "not_legal",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{3}{R}{G}",
#     "mtgo_foil_id": 65475,
#     "mtgo_id": 65474,
#     "multiverse_ids": [
#         435383
#     ],
#     "name": "Regisaur Alpha",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "0673f4e0-66ff-458c-b4ba-eb067e560cce",
#     "oracle_text": "Other Dinosaurs you control have haste.\nWhen Regisaur Alpha enters the battlefield, create a 3/3 green Dinosaur creature token with trample.",
#     "oversized": false,
#     "penny_rank": 7389,
#     "power": "4",
#     "prices": {
#         "eur": "0.77",
#         "eur_foil": "2.66",
#         "tix": "0.02",
#         "usd": "1.18",
#         "usd_etched": null,
#         "usd_foil": "7.31"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3A0673f4e0-66ff-458c-b4ba-eb067e560cce&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65474?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Regisaur-Alpha?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F144964%3Fpage%3D1"
#     },
#     "rarity": "rare",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Regisaur+Alpha",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435383&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DRegisaur%2BAlpha",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DRegisaur%2BAlpha"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/d6a322c5-aa4c-4a99-a3ca-48c1353104f0/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/227/regisaur-alpha?utm_source=api",
#     "security_stamp": "oval",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 144964,
#     "textless": false,
#     "toughness": "4",
#     "type_line": "Creature \u2014 Dinosaur",
#     "uri": "https://api.scryfall.com/cards/d6a322c5-aa4c-4a99-a3ca-48c1353104f0",
#     "variation": false
# }
# ####################################################################################################
# {
#     "arena_id": 66277,
#     "artist": "Dan Murayama Scott",
#     "artist_ids": [
#         "f852fa13-137e-40f2-bbc1-0f01df09c0e0"
#     ],
#     "booster": true,
#     "border_color": "black",
#     "card_back_id": "0aeebaf5-8c7d-4636-9e82-8c27447861f7",
#     "cardmarket_id": 301799,
#     "cmc": 3.0,
#     "collector_number": "156",
#     "color_identity": [
#         "R"
#     ],
#     "colors": [
#         "R"
#     ],
#     "digital": false,
#     "edhrec_rank": 20423,
#     "finishes": [
#         "nonfoil",
#         "foil"
#     ],
#     "foil": true,
#     "frame": "2015",
#     "full_art": false,
#     "games": [
#         "arena",
#         "paper",
#         "mtgo"
#     ],
#     "highres_image": true,
#     "id": "ba90a2d6-8292-4ff1-91d0-b30ae9775f12",
#     "illustration_id": "151e5f66-9f61-4077-84a9-00384682b323",
#     "image_status": "highres_scan",
#     "image_uris": {
#         "art_crop": "https://cards.scryfall.io/art_crop/front/b/a/ba90a2d6-8292-4ff1-91d0-b30ae9775f12.jpg?1562562987",
#         "border_crop": "https://cards.scryfall.io/border_crop/front/b/a/ba90a2d6-8292-4ff1-91d0-b30ae9775f12.jpg?1562562987",
#         "large": "https://cards.scryfall.io/large/front/b/a/ba90a2d6-8292-4ff1-91d0-b30ae9775f12.jpg?1562562987",
#         "normal": "https://cards.scryfall.io/normal/front/b/a/ba90a2d6-8292-4ff1-91d0-b30ae9775f12.jpg?1562562987",
#         "png": "https://cards.scryfall.io/png/front/b/a/ba90a2d6-8292-4ff1-91d0-b30ae9775f12.png?1562562987",
#         "small": "https://cards.scryfall.io/small/front/b/a/ba90a2d6-8292-4ff1-91d0-b30ae9775f12.jpg?1562562987"
#     },
#     "keywords": [
#         "Raid"
#     ],
#     "lang": "en",
#     "layout": "normal",
#     "legalities": {
#         "alchemy": "not_legal",
#         "brawl": "legal",
#         "commander": "legal",
#         "duel": "legal",
#         "explorer": "legal",
#         "future": "not_legal",
#         "gladiator": "legal",
#         "historic": "legal",
#         "legacy": "legal",
#         "modern": "legal",
#         "oathbreaker": "legal",
#         "oldschool": "not_legal",
#         "pauper": "not_legal",
#         "paupercommander": "not_legal",
#         "penny": "legal",
#         "pioneer": "legal",
#         "predh": "not_legal",
#         "premodern": "not_legal",
#         "standard": "not_legal",
#         "standardbrawl": "not_legal",
#         "timeless": "legal",
#         "vintage": "legal"
#     },
#     "mana_cost": "{1}{R}{R}",
#     "mtgo_foil_id": 65329,
#     "mtgo_id": 65328,
#     "multiverse_ids": [
#         435310
#     ],
#     "name": "Repeating Barrage",
#     "nonfoil": true,
#     "object": "card",
#     "oracle_id": "a08c599e-ee75-4d2b-ae9b-0987c233dd17",
#     "oracle_text": "Repeating Barrage deals 3 damage to any target.\nRaid \u2014 {3}{R}{R}: Return Repeating Barrage from your graveyard to your hand. Activate only if you attacked this turn.",
#     "oversized": false,
#     "penny_rank": 10462,
#     "prices": {
#         "eur": "0.09",
#         "eur_foil": "0.18",
#         "tix": "0.02",
#         "usd": "0.09",
#         "usd_etched": null,
#         "usd_foil": "0.29"
#     },
#     "prints_search_uri": "https://api.scryfall.com/cards/search?order=released&q=oracleid%3Aa08c599e-ee75-4d2b-ae9b-0987c233dd17&unique=prints",
#     "promo": false,
#     "purchase_uris": {
#         "cardhoarder": "https://www.cardhoarder.com/cards/65328?affiliate_id=scryfall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall",
#         "cardmarket": "https://www.cardmarket.com/en/Magic/Products/Singles/Ixalan/Repeating-Barrage?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall",
#         "tcgplayer": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F145640%3Fpage%3D1"
#     },
#     "rarity": "rare",
#     "related_uris": {
#         "edhrec": "https://edhrec.com/route/?cc=Repeating+Barrage",
#         "gatherer": "https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=435310&printed=false",
#         "tcgplayer_infinite_articles": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Darticle%26game%3Dmagic%26partner%3Dscryfall%26q%3DRepeating%2BBarrage",
#         "tcgplayer_infinite_decks": "https://tcgplayer.pxf.io/c/4931599/1830156/21018?subId1=api&trafcat=infinite&u=https%3A%2F%2Finfinite.tcgplayer.com%2Fsearch%3FcontentMode%3Ddeck%26game%3Dmagic%26partner%3Dscryfall%26q%3DRepeating%2BBarrage"
#     },
#     "released_at": "2017-09-29",
#     "reprint": false,
#     "reserved": false,
#     "rulings_uri": "https://api.scryfall.com/cards/ba90a2d6-8292-4ff1-91d0-b30ae9775f12/rulings",
#     "scryfall_set_uri": "https://scryfall.com/sets/xln?utm_source=api",
#     "scryfall_uri": "https://scryfall.com/card/xln/156/repeating-barrage?utm_source=api",
#     "security_stamp": "oval",
#     "set": "xln",
#     "set_id": "fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "set_name": "Ixalan",
#     "set_search_uri": "https://api.scryfall.com/cards/search?order=set&q=e%3Axln&unique=prints",
#     "set_type": "expansion",
#     "set_uri": "https://api.scryfall.com/sets/fe0dad85-54bc-4151-9200-d68da84dd0f2",
#     "story_spotlight": false,
#     "tcgplayer_id": 145640,
#     "textless": false,
#     "type_line": "Sorcery",
#     "uri": "https://api.scryfall.com/cards/ba90a2d6-8292-4ff1-91d0-b30ae9775f12",
#     "variation": false
# }
# ####################################################################################################

# %%
# Out:
# ['object',
#  'id',
#  'oracle_id',
#  'multiverse_ids',
#  'mtgo_id',
#  'mtgo_foil_id',
#  'arena_id',
#  'tcgplayer_id',
#  'cardmarket_id',
#  'name',
#  'lang',
#  'released_at',
#  'uri',
#  'scryfall_uri',
#  'layout',
#  'highres_image',
#  'image_status',
#  'image_uris',
#  'mana_cost',
#  'cmc',
#  'type_line',
#  'oracle_text',
#  'power',
#  'toughness',
#  'colors',
#  'color_identity',
#  'keywords',
#  'legalities',
#  'games',
#  'reserved',
#  'foil',
#  'nonfoil',
#  'finishes',
#  'oversized',
#  'promo',
#  'reprint',
#  'variation',
#  'set_id',
#  'set',
#  'set_name',
#  'set_type',
#  'set_uri',
#  'set_search_uri',
#  'scryfall_set_uri',
#  'rulings_uri',
#  'prints_search_uri',
#  'collector_number',
#  'digital',
#  'rarity',
#  'card_back_id',
#  'artist',
#  'artist_ids',
#  'illustration_id',
#  'border_color',
#  'frame',
#  'full_art',
#  'textless',
#  'booster',
#  'story_spotlight',
#  'edhrec_rank',
#  'penny_rank',
#  'prices',
#  'related_uris',
#  'purchase_uris']

# %%
from utils.sets import set_cards

set_cards('xln')
